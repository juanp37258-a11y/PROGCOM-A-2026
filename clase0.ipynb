# %% [markdown]
# Aprendiendo a usar print

# %% [markdown]
# print() es un metodo que permite imprimir informacion en la consola

# %%
condicion = True
if condicion:
    print("pasan cositas")
else:
    print("pasan otras cositas")
# Out:
# pasan cositas

# %% [markdown]
# el print() puede imprimir lo siguiente
#
# 1.cualquier tipo de dato
# 2.cualquier metodo de funcion(su direccion en memoria)
# 3.concatenacion de texto
# 4.operaciones matematicas

# %% [markdown]
# conociendo el input
#
# input() es un metodo triple con funcion
#  *declara:toda la informacion que ingresa con este metodo,se declara
#  automaticamente como string(caracter)
#  *lee:porque almacena en una variable
#  *imprime:porque lo que esta entre los parentesis se visualiza en cosola

# %%
a = input()
b = input()
print(a + b)

# %% [markdown]
# concatenacion

# %%
x=int(input("ingrese su edad:"))
# Out:
# ingrese su edad:78
